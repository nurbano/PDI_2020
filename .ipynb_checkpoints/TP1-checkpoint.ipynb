# %%
from PIL import Image #Libreria PILLOW
import numpy as np    #Libreria NUMPY
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Abro imagen
im= Image.open("grasa.jpg")
im1 = im.resize((350, 350)) 
a= np.asarray(im1)

# %% [markdown]
# ## Transformación a espacio YIQ
# Y = 0.299*R + 0.587*G + 0.114*B \
# I = 0.595716*R – 0.274453*G – 0.321263*B \
# Q = 0.211456*R – 0.522591*G + 0.311135*B

# %%
#Normalizo los bytes RGB
a_norm= a/256

# %%
#Armo la matriz de transformación
mat_a_YIQ= np.array([[0.299,0.587,0.114],[0.595716,-0.274453,-0.321263],[0.211456,-0.522591,0.311135]])
mat_a_YIQ.T
# Out:
# array([[ 0.299   ,  0.595716,  0.211456],
#        [ 0.587   , -0.274453, -0.522591],
#        [ 0.114   , -0.321263,  0.311135]])

# %%
#Realizo el producto vectorial
b= np.dot(a_norm, mat_a_YIQ.T)

# %%
#Creo una matriz para transformar alpha y beta
alpha= 0.7
beta= 1
coe= [alpha,beta,beta]
coe
# Out:
# [0.7, 1, 1]

# %%
ancho= b.shape[0]
alto= b.shape[1]
prof= b.shape[2]

# %%
#Multiplico escalarmente la matriz YIQ por la matriz de coeficientes
c= b*coe

# %%
#Hago la correción de Y, I y Q
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q")

# %% [markdown]
# ## Transformación YIQ a RGB
# R=Y+0.956*I+0.621*Q \
# G=Y-0.272*I-0.647*Q \
# B=Y-1.106*I+1.703*Q

# %%
#Armo la matriz de transformación
mat_a_RGB= np.array([[1,0.9663,0.6210],[1,-0.2721,-0.6474],[1,-1.1070,1.7046]])
mat_a_RGB.T
# Out:
# array([[ 1.    ,  1.    ,  1.    ],
#        [ 0.9663, -0.2721, -1.107 ],
#        [ 0.621 , -0.6474,  1.7046]])

# %%
#Hago el productor vectorial en la imágen en el espacio YIQ y la matriz de transformación
g= np.dot(d, mat_a_RGB.T)
#Normalizo los bytes
g_bytes= g*255
#Realizo correción para evitar errores cuando convierto de float a uint8
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
#Convierto de float a uint8 para poder representar la imagen
e= g_bytes.astype(np.uint8)

# %%
im2= Image.fromarray(e)

# %%
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Alpha 0.7")
# Out:
# Text(0.5, 1.0, 'Alpha 0.7')

# %%
alpha= 0.4
beta= 1
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Alpha 0.4")
# Out:
# Text(0.5, 1.0, 'Alpha 0.4')

# %%
alpha= 1.2
beta= 1
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Alpha 1.2")
# Out:
# Text(0.5, 1.0, 'Alpha 1.2')

# %%
alpha= 1.5
beta= 1
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Alpha 1.5")
# Out:
# Text(0.5, 1.0, 'Alpha 1.5')

# %%
alpha= 1
beta= 0.5
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Beta 0.5")
# Out:
# Text(0.5, 1.0, 'Beta 0.5')

# %%
alpha= 1
beta= 0
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Beta 0")
# Out:
# Text(0.5, 1.0, 'Beta 0')

# %%
alpha= 1
beta= 1.2
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Beta 1.2")
# Out:
# Text(0.5, 1.0, 'Beta 1.2')

# %%
alpha= 1
beta= 1.5
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Beta 1.5")
# Out:
# Text(0.5, 1.0, 'Beta 1.5')

# %%
alpha= 0.7
beta= 1.8
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Alpha 0.7 / Beta=1.8")
# Out:
# Text(0.5, 1.0, 'Alpha 0.7 / Beta=1.8')

# %%
alpha= 0.4
beta= 0.3
coe= [alpha,beta,beta]
c= b*coe
d=np.zeros([ancho,alto,prof])
for x in range(ancho):
    for y in range(alto):
        d[x][y][0]=c[x][y][0]
        d[x][y][1]=c[x][y][1]
        d[x][y][2]=c[x][y][2]
        if c[x][y][0]>1:
            d[x][y][0]=1
            #print("Corregí Y")
            
        if  c[x][y][1]>0.5957:
            d[x][y][1]= 0.5957
            #print("Corregí I")
            
        if  c[x][y][1]<-0.5957:
            d[x][y][1]= -0.5957
            #print("Corregí I")
            
        if  c[x][y][2]>0.5226:
            d[x][y][2]= 0.5226
            #print("Corregí Q")
            
        if  c[x][y][2]<-0.5226:
            d[x][y][2]= -0.5226
            #print("Corregí Q") 
g= np.dot(d, mat_a_RGB.T)
g_bytes= g*255
g_bytes[g_bytes<0] = 0
g_bytes[g_bytes>255] =255
e= g_bytes.astype(np.uint8)
im2= Image.fromarray(e)
plt.subplot(121), plt.imshow(im1)
plt.title("Original")

plt.subplot(122), plt.imshow(im2)
plt.title("Alpha 0.4")
# Out:
# Text(0.5, 1.0, 'Alpha 0.4')

# %% [markdown]
# ## Mapas Cromáticos

# %%
#Genero un dataset
# Generate some test data
x = np.random.randn(8873)
y = np.random.randn(8873)

heatmap, xedges, yedges = np.histogram2d(x, y, bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.imshow(heatmap.T)
plt.show()
#Pruebo diferetes mapas cromáticos de la librería matplotlib
#https://matplotlib.org/3.2.1/tutorials/colors/colormaps.html

# %%
plt.imshow(heatmap.T, cmap="BuPu")
plt.show()

# %%
plt.imshow(heatmap.T, cmap="Greys")
plt.show()

# %%
plt.imshow(heatmap.T, cmap="hsv")
plt.show()

# %%
plt.imshow(heatmap.T, cmap="Spectral")
plt.show()
